# %% [markdown]
# # DANAM Image Metadata Notebook
# This notebook is used along with the scripts clean_json and caption_processing and to query and analyze DANAM's image metadata quickly.
#
# Queries is done via Pandas Dataframe.

# %%
from scripts.SDS import *
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# %%
root = 'Z:\\Data\\Monuments\\'
mon_id = 'bal0002'

# %%
get_images(root, mon_id)
# Out:
#                        filename filetypes   image_type
# 0     BAL0002-001_P_20210613-01       NEF   photograph
# 1     BAL0002-001_P_20210613-02       NEF  inscription
# 2     BAL0002-001_P_20210613-03       NEF   photograph
# 3     BAL0002-002_P_20210703-01       NEF  inscription
# 4     BAL0002-002_P_20210703-02       NEF      drawing
# 5     BAL0002_D_2021_floor_plan       pdf   photograph
# 6   BAL0002_D_2021_location_map       pdf  inscription
# 7      BAL0002_D_2021_site_plan       pdf   photograph
# 8     BAL0002_I_001_20210613-01       NEF   photograph
# 9     BAL0002_I_001_20210613-02       NEF   photograph
# 10    BAL0002_I_002_20210613-01       NEF      drawing
# 11    BAL0002_I_003_20210613-01       NEF   photograph
# 12    BAL0002_I_004_20210613-01       NEF   photograph
# 13    BAL0002_I_005_20210807-01       ARW   photograph
# 14        BAL0002_P_20210613-07       NEF   photograph
# 15        BAL0002_P_20210613_01       NEF   photograph
# 16        BAL0002_P_20210613_02       NEF      drawing
# 17        BAL0002_P_20210613_03       NEF  inscription
# 18        BAL0002_P_20210613_04       NEF   photograph
# 19        BAL0002_P_20210613_05       NEF  inscription
# 20        BAL0002_P_20210613_06       NEF  inscription
# 21        BAL0002_P_20210706-01       NEF   photograph
# 22        BAL0002_P_20210706-02       NEF   photograph
# 23        BAL0002_P_20210706-03       NEF   photograph
# 24        BAL0002_P_20210706-04       NEF   photograph
