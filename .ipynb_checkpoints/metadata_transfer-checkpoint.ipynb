# %% [markdown]
# # DANAM Image Metadata Notebook
# This notebook is used along with the scripts clean_json and write_csv to query and analyze DANAM's image metadata quickly.
#
# Queries is done via Pandas Dataframe.

# %%
import csv
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)

#from datetime import datetime

from scripts.clean_json import clean_json
from scripts.write_csv import list_from_txt
from scripts.metadata_fix import manual_fixes

def print_df(df):
    cols = [
        'danam_caption', 'caption', 'date1', 'date2', 'date', 'date3', 'agent', 'role', 'agent2', 'role2', 'source', 'notes', 'mon_id', 'class_code', 'classification', 'agent3', 'date_scan',
        ]
    return df[cols]

# %% [markdown]
# ## Read DANAM json export
# Always replace with the latest export

# %%
# read DANAM json export
danam_export = "json\DANAM\Monument_2022-03-07_23-32-03.json"
danam_images = clean_json(danam_export)
danam_df = pd.DataFrame(danam_images)

# %% [markdown]
# ## Preparing Metadata Uploads
# ### Metadata of monuments in upload_current.mon

# %%
# find recently updated monuments
mon_ids = list_from_txt('mon/upload_current.mon')

# Filter metadata according to current.mon and valid caption
to_upload = danam_df.loc[danam_df['mon_id'].isin(mon_ids)]
to_upload = to_upload.loc[to_upload['validCaption']]

## manual fixes start ##
fixes = "fixes//current.fix"
manual_fixes(to_upload, fixes)
## manual fixes end ##

print_df(to_upload)
# Out:
#                                                                                                                                                                                   danam_caption  \
# 1803                                                                     Caturbrahma Mahāvihāra; location map by Niels Gutschow,  Surendra Joshi; 1986; updated by Anil Basukala, 2021-08-10
# 1804                                                                                                                       Caturbrahma Mahāvihāra; E-W section by Bijay Basukala; 2021-08-18
# 1805                                                                                                                          Caturbrahma Mahāvihāra; site plan by Anil Basukala; 2021-08-28
# 1806                                                                                                                         Caturbrahma Mahāvihāra; floor plan by Anil Basukala; 2021-08-28
# 1807                                                                                                Caturbrahma Mahāvihāra, inner courtyard, view from W; photo by Bijay Basukala; 2021-08-27
# ...                                                                                                                                                                                         ...
# 21226                                                                                                 Chipur Hat Pat Naulo, interior, view from west; photo by David C Andolfatto; 2015-04-24
# 21227                                                                                                  Chipur Hat Pat Naulo, ceiling, view from west; photo by David C Andolfatto; 2015-04-24
# 21228  Chipur Hat Pat Naulo, first floor pillar, view from south-west; photo by David C Andolfatto; 2015-04-24  The pillar is decorated with carvings of warriors, horseriders and quadrupeds
# 21229                                                                                            Chipur Hat Pat Naulo, ceiling, view from south-west; photo by David C Andolfatto; 2015-04-24
# 21230                                                                       Chipur Hat Pat Naulo, small reservoir and terraces, view from north-west; photo by David C Andolfatto; 2015-04-24
#
#                                                                         caption  \
# 1803                                       Caturbrahma Mahāvihāra, location map
# 1804                                        Caturbrahma Mahāvihāra, E-W section
# 1805                                          Caturbrahma Mahāvihāra, site plan
# 1806                                         Caturbrahma Mahāvihāra, floor plan
# 1807                       Caturbrahma Mahāvihāra, inner courtyard, view from W
# ...                                                                         ...
# 21226                            Chipur Hat Pat Naulo, interior, view from west
# 21227                             Chipur Hat Pat Naulo, ceiling, view from west
# 21228            Chipur Hat Pat Naulo, first floor pillar, view from south-west
# 21229                       Chipur Hat Pat Naulo, ceiling, view from south-west
# 21230  Chipur Hat Pat Naulo, small reservoir and terraces, view from north-west
#
#       date1 date2        date date3    agent          role   agent2  \
# 1803                     1986        1248173     draftsman  1367714
# 1804               2021-08-18        1156661     draftsman
# 1805               2021-08-28        1173868     draftsman
# 1806               2021-08-28        1173868     draftsman
# 1807               2021-08-27        1156661  photographer
# ...     ...   ...         ...   ...      ...           ...      ...
# 21226              2015-04-24        1248176  photographer
# 21227              2015-04-24        1248176  photographer
# 21228              2015-04-24        1248176  photographer
# 21229              2015-04-24        1248176  photographer
# 21230              2015-04-24        1248176  photographer
#
#            role2 source  \
# 1803   draftsman
# 1804
# 1805
# 1806
# 1807
# ...          ...    ...
# 21226
# 21227
# 21228
# 21229
# 21230
#
#                                                                                 notes  \
# 1803
# 1804
# 1805
# 1806
# 1807
# ...                                                                               ...
# 21226
# 21227
# 21228  The pillar is decorated with carvings of warriors, horseriders and quadrupeds.
# 21229
# 21230
#
#         mon_id class_code         classification   agent3 date_scan
# 1803   BKT0400  4029783-4                  Karte  1173868
# 1804   BKT0400  4068827-6   Architekturzeichnung
# 1805   BKT0400  4068827-6   Architekturzeichnung
# 1806   BKT0400  4068827-6   Architekturzeichnung
# 1807   BKT0400  4002855-0  Architekturfotografie
# ...        ...        ...                    ...      ...       ...
# 21226  DDL0280  4002855-0  Architekturfotografie
# 21227  DDL0280  4002855-0  Architekturfotografie
# 21228  DDL0280  4002855-0  Architekturfotografie
# 21229  DDL0280  4002855-0  Architekturfotografie
# 21230  DDL0280  4002855-0  Architekturfotografie
#
# [691 rows x 17 columns]

# %% [markdown]
# ### Metadata of recently updloaded maps

# %%
only_maps = list_from_txt("mon\\upload_only_maps.mon")

upload_map = danam_df.loc[danam_df['mon_id'].isin(only_maps)]
upload_map = upload_map.loc[upload_map['validCaption']]
upload_map = upload_map.loc[upload_map['filename'].str.contains("_D_")]

## manual fixes start ##
fixes = "fixes\\maps.fix"
manual_fixes(upload_map, fixes)
## manual fixes end ##

print_df(upload_map)
# Out:
#                                                                                                    danam_caption  \
# 2389                                             Chumāgaṇeśa Mandira; site plan by Anil Basukala;  2021-11-21
# 2390                                            Chumāgaṇeśa Mandira; floor plan by Anil Basukala;  2021-11-21
# 2408      Chumāgaṇeśa Mandira; location map by Niels Gutschow; 1987; updated by by Anil Basukala;  2021-11-08
# 3544                                                    Jayabali Dyaḥ; top view by Bijay Basukala; 2022-02-13
# 3545                                                     Jayabali Dyaḥ; section by Bijay Basukala; 2022-02-13
# 3546                                                   Jayabali Dyaḥ; site plan by Bijay Basukala; 2022-02-13
# 3547                  Jayabali Dyaḥ; location map by Thomas Schrom 2021; updated by Anil Basukala, 2022-02-13
# 4196                Taḥnani Phalcā; location map by Reinhard Herdick; 1975; updated by Thomas Schrom, 2021-10
# 4197                   Taḥnani Phalcā; site plan by Reinhard Herdick; 1975; updated by Thomas Schrom, 2021-10
# 4198                                                     Taḥnani Phalcā; floor plan by Thomas Schrom; 2021-10
# 4196                 Taḥnani Phalcā, location map                    1975
# 4197                    Taḥnani Phalcā, site plan                    1975
# 4198                   Taḥnani Phalcā, floor plan                 2021-10
# 4221              Taḥnani Phalcā, section drawing                 2021-10
# 5000                        Laṃkva Hiti, top view              2022-02-18
# 5001                    Laṃkva Hiti, location map                    2021
# 5002                       Laṃkva Hiti, site plan              2022-02-18
# 5159   Mahālakṣmī Shrine Phalcā, location map                    2021
# 5160      Mahālakṣmī Shrine Phalcā, site plan              2022-02-25
# 5161     Mahālakṣmī Shrine Phalcā, floor plan              2022-02-25
# 5220                     Suye Bāhāḥ, location map                    2021
# 5221                        Suye Bāhāḥ, site plan              2022-02-24
# 5222                       Suye Bāhāḥ, floor plan              2022-02-24
# 6584      Lakṣmīnārāyaṇa Mandira, floor plan              2022-03-07
# 6585    Lakṣmīnārāyaṇa Mandira, location map                    2021
# 6586       Lakṣmīnārāyaṇa Mandira, site plan              2022-03-07
# 9562           Ipātvāḥ Nāsaḥdyaḥ, site plan              2022-02-25
# 9563        Ipātvāḥ Nāsaḥdyaḥ, location map                    2021
# 9564             Ipātvāḥ Nāsaḥdyaḥ, section              2022-02-25
# 9565          Ipātvāḥ Nāsaḥdyaḥ, floor plan              2022-02-25
# 9640               Simākva Nārāyaṇa, site plan              2022-03-03
# 9641              Simākva Nārāyaṇa, floor plan              2022-03-03
# 9642            Simākva Nārāyaṇa, location map                    2021
# 19582        Calākhutvāh Gaṇeśa, location map                    2021
# 19583             Calākhutvāh Gaṇeśa, section              2022-03-07
# 19584          Calākhutvāh Gaṇeśa, floor plan              2022-03-07
# 19585           Calākhutvāh Gaṇeśa, site plan              2022-03-07
# 21690                 Samay Phalcā, location map              2022-02-22
# 21691                      Samay Phalcā, section              2022-02-24
# 21692                   Samay Phalcā, floor plan              2022-02-24
# 21693                    Samay Phalcā, site plan              2022-02-24
#
#       date3    agent       role agent2 role2 source notes   mon_id class_code  \
# 2389         1173868  draftsman                            BKT0151  4068827-6
# 2390         1173868  draftsman                            BKT0151  4068827-6
# 2408         1248173  draftsman                            BKT0151  4029783-4
# 3544         1156661  draftsman                            SKH0230  4068827-6
# 3545         1156661  draftsman                            SKH0230  4068827-6
# 3546         1156661  draftsman                            SKH0230  4068827-6
# 3547         1248182  draftsman                            SKH0230  4029783-4
# 4196         1249903  draftsman                            KIR4012  4029783-4
# 4197         1249903  draftsman                            KIR4012  4068827-6
# 4198         1248182  draftsman                            KIR4012  4068827-6
# 4221         1248182  draftsman                            KIR4012  4068827-6
# 5000         1173868  draftsman                            SKH0223  4068827-6
# 5001         1248182  draftsman                            SKH0223  4029783-4
# 5002         1173868  draftsman                            SKH0223  4068827-6
# 5159         1248182  draftsman                            SKH0161  4029783-4
# 5160         1173868  draftsman                            SKH0161  4068827-6
# 5161         1173868  draftsman                            SKH0161  4068827-6
# 5220         1248182  draftsman                            SKH0254  4029783-4
# 5221         1238506  draftsman                            SKH0254  4068827-6
# 5222         1238506  draftsman                            SKH0254  4068827-6
# 6584         1173868  draftsman                            SKH0170  4068827-6
# 6585         1248182  draftsman                            SKH0170  4029783-4
# 6586         1173868  draftsman                            SKH0170  4068827-6
# 9562         1173868  draftsman                            SKH0280  4068827-6
# 9563                  draftsman                            SKH0280  4029783-4
# 9564         1156661  draftsman                            SKH0280  4068827-6
# 9565         1156661  draftsman                            SKH0280  4068827-6
# 9640         1238506  draftsman                            SKH0300  4068827-6
# 9641         1238506  draftsman                            SKH0300  4068827-6
# 9642         1248182  draftsman                            SKH0300  4029783-4
# 19582        1248182  draftsman                            SKH0180  4029783-4
# 19583        1173868  draftsman                            SKH0180  4068827-6
# 19584        1173868  draftsman                            SKH0180  4068827-6
# 19585        1173868  draftsman                            SKH0180  4068827-6
# 21690        1173868  draftsman                            LAL4317  4029783-4
# 21691        1156661  draftsman                            LAL4317  4068827-6
# 21692        1156661  draftsman                            LAL4317  4068827-6
# 21693        1173868  draftsman                            LAL4317  4068827-6
#
#              classification   agent3    date_scan
# 2389   Architekturzeichnung
# 2390   Architekturzeichnung
# 2408                  Karte  1173868   2021-11-21
# 3544   Architekturzeichnung
# 3545   Architekturzeichnung
# 3546   Architekturzeichnung
# 3547                  Karte  1173868   2022-02-13
# 4196                  Karte  1248182   2021-10
# 4197   Architekturzeichnung  1248182   2021-10
# 4198   Architekturzeichnung
# 4221   Architekturzeichnung
# 5000   Architekturzeichnung
# 5001                  Karte  1173868   2022-02-18
# 5002   Architekturzeichnung
# 5159                  Karte  1173868   2022-02-25
# 5160   Architekturzeichnung
# 5161   Architekturzeichnung
# 5220                  Karte  1238506   2022-02-24
# 5221   Architekturzeichnung
# 5222   Architekturzeichnung
# 6584   Architekturzeichnung
# 6585                  Karte  1173868   2022-03-07
# 6586   Architekturzeichnung
# 9562   Architekturzeichnung
# 9563                  Karte  1173868   2022-02-25
# 9564   Architekturzeichnung
# 9565   Architekturzeichnung
# 9640   Architekturzeichnung
# 9641   Architekturzeichnung
# 9642                  Karte  1238506   2022-03-03
# 19582                 Karte  1173868   2022-03-07
# 19583  Architekturzeichnung
# 19584  Architekturzeichnung
# 19585  Architekturzeichnung
# 21690                 Karte
# 21691  Architekturzeichnung
# 21692  Architekturzeichnung
# 21693  Architekturzeichnung

# %% [markdown]
# ### Metadata of recently updloaded historical images

# %%
only_historical = list_from_txt("mon\\upload_only_historical.mon")

upload_historical = danam_df.loc[danam_df['mon_id'].isin(only_historical)]
upload_historical = upload_historical.loc[upload_historical['validCaption']]
upload_historical = upload_historical.loc[upload_historical['filename'].str.contains("_H_")]

## manual fixes start ##
fixes = "fixes\\historical.fix"
manual_fixes(upload_historical, fixes)
## manual fixes end ##

print_df(upload_historical)
# Out:
#                                                                                                                                                                                                                                                                                 danam_caption  \
# 4220                                                                                                            Taḥnani Phalcā, view from W; photo by Carl Pruscha; 1973–1974; courtesy of Carl Pruscha; free access – no reuse; source: Carl Pruscha, Kathmandu Valley, 1975, vol I, p 119
# 11251                                                                                                                                              Lāykū Hiti, view from W; photo by Peter Bachmayer; 2010-11; courtesy of Peter Bachmayer; free access – no reuse; source: Peter Bachmayer
# 11252  Lyākū Hiti, view from NW; photo by John C Huntington; 1984; courtesy of the John C and Susan L Huntington Photographic Archive of Buddhist and Asian Art; free access – no reuse; source: The Huntington Archive  Please visit the Huntington Archive for more photos of this Temple
# 11566                                                                                                             Sālkhā Dabū, , view from W; photo by Carl Pruscha; 1973–1974; courtesy of Carl Pruscha; free access – no reuse; source: Carl Pruscha, Kathmandu Valley, 1975, vol I, p 73
# 13503                                                                                                           Taḥnani Caitya, view from W; photo by Carl Pruscha; 1973–1974; courtesy of Carl Pruscha; free access – no reuse; source: Carl Pruscha, Kathmandu Valley, 1975, vol I, p 119
#
#                            caption date1 date2     date date3    agent  \
# 4220   Taḥnani Phalcā, view from W                 1973  1974  1173886
# 11251      Lāykū Hiti, view from W              2010-11        1575554
# 11252     Lyākū Hiti, view from NW                 1984        1369252
# 11566   Sālkhā Dabū, , view from W                 1973  1974  1173886
# 13503  Taḥnani Caitya, view from W                 1973  1974  1173886
#
#                role agent2 role2  \
# 4220   photographer
# 11251  photographer
# 11252  photographer
# 11566  photographer
# 13503  photographer
#
#                                                                                            source  \
# 4220                                           Carl Pruscha, Kathmandu Valley, 1975, vol I, p 119
# 11251                                                                             Peter Bachmayer
# 11252  The Huntington Archive  Please visit the Huntington Archive for more photos of this Temple
# 11566                                           Carl Pruscha, Kathmandu Valley, 1975, vol I, p 73
# 13503                                          Carl Pruscha, Kathmandu Valley, 1975, vol I, p 119
#
#                                                                      notes  \
# 4220
# 11251
# 11252  Please visit the Huntington Archive for more photos of this Temple.
# 11566
# 13503
#
#         mon_id class_code         classification agent3 date_scan
# 4220   KIR4012  4002855-0  Architekturfotografie
# 11251  BKT0092  4002855-0  Architekturfotografie
# 11252  BKT0092  4002855-0  Architekturfotografie
# 11566  SKH0141  4002855-0  Architekturfotografie
# 13503  KIR0075  4002855-0  Architekturfotografie

# %% [markdown]
# ### Finding recently updated monuments

# %%
from datetime import datetime

recent = danam_df.loc[danam_df['lastModified'] >= datetime(2022, 2, 15)]
print("Number of recently update monuments: {}".format(recent.shape[0]))
recent_mon_ids = set(list(set(recent['mon_id'])))

uploaded = list_from_txt('mon\\sds.mon')
to_update_mon = [mon for mon in recent_mon_ids if mon in uploaded and mon not in mon_ids and mon not in only_maps and mon not in only_historical]
print("Number of those monuments already uploaded to HeidIcon that are not in current.mon: {}".format(len(to_update_mon)))

file = open("mon\\recently_changed.mon", 'w')
for mon_id in to_update_mon:
    file.write(mon_id+"\n")
file.close()

to_update = danam_df.loc[danam_df['mon_id'].isin(to_update_mon)]
to_update = to_update.loc[to_update['validCaption']]    
to_update = to_update.loc[to_update['lastModified'] > datetime(2022, 2, 15)]

## manual fixes start ##
fixes = "fixes\\update.fix"
manual_fixes(to_update, fixes)
## manual fixes end ##

#to_update[[ 'lastModified', 'validCaption', 'filename', 'danam_caption', 'caption', 'date', 'agent']].sort_values('lastModified', ascending=False)
print_df(to_update)
# Out:
# Number of recently update monuments: 197
# 13261                                                                                                                                Dhalāṃkva Hiti, statue of Umāmaheśvara, view from E; photo by Yogesh Budathoki; 2022-01-16
# 13262                                                                                                                                                        Dhalāṃkva Hiti, view from E; photo by Yogesh Budathoki; 2022-01-16
# 13263                                                                                                                                                        Dhalāṃkva Hiti, view from W; photo by Yogesh Budathoki; 2022-01-16
# 13594                       Subāhāḥ Hiti Phalcā, Mātṛkā Vaiṣṇavī, view from S; photo by Jürgen Schick; 1987-01-30; courtesy of Ulrich von Schroeder; free access – no reuse; source: Nepalese Stone Sculptures, 2019, vol I, 54
# 19990                          Misā Hiti, pair of Yakṣa, view from S; photo by Ulrich von Schroeder; 2012-08-27;  courtesy of Ulrich von Schroeder; free access – no reuse; source: Nepalese Stone Sculptures, 2019, vol I, 105
# 20125                                Lāchi Hiti, Yakṣa-Caryatid, view from E; photo by Sunil Dangol;  2014-11-16;  courtesy of Ulrich von Schroeder; free access – no reuse; source: Nepalese Stone Sculptures, 2019, vol I, 96
# 21210                                                                                                                       Suntvāḥ Phalcā (South); location map by Thomas Schrom; 2021; updated by Anil Basukala, 2022-02-18
# 21211                                                                                                                                                         Suntvāḥ Phalcā (South); floor plan by Anil Basukala; 2022-02-18
# 21213                                                                                                                                                            Suntvāḥ Phalcā (South); section by Anil Basukala; 2022-02-18
# 21214                                                                                                                                                          Suntvāḥ Phalcā (South); site plan by Anil Basukala; 2022-02-18
#
#                                                                       caption  \
# 704                                          Lũ Hiti, Śivaliṅga, view from N
# 3014                                    Suntvāḥ Phalcā (North), location map
# 3015                                      Suntvāḥ Phalcā (North), floor plan
# 3016                                       Suntvāḥ Phalcā (North), site plan
# 3017                                         Suntvāḥ Phalcā (North), section
# 6133                                  Cyāsaḥ Hiṭī, pair of Yakṣa, view from S
# 6136                         Cyāsaḥ Hiṭī, Caturmukha Śiva Liṅga, view from NW
# 8695                                 Baḥsimākva Dyaḥ, close-up view, from E
# 8696                                          Baḥsimākva Dyaḥ, view from SE
# 8703                       Baḥsimākva Dyaḥ, unidentified deity, view from E
# 8704                 Baḥsimākva Dyaḥ, statue of Lakṣmīnārāyaṇa, view from E
# 9605                                  Dharmadhātujinālaya Caitya, site plan
# 9879                                  Dugāḥhiti Gaṇeśa Phalcā, floor plan
# 9880                                Dugāḥhiti Gaṇeśa Phalcā, location map
# 9881                                   Dugāḥhiti Gaṇeśa Phalcā, site plan
# 9882                             Dugāḥhiti Gaṇeśa Phalcā, section drawing
# 11091                                    Gaṇeśa Mandira, Kaumārī, view from N
# 11092                            Gaṇeśa Mandira, Mātṛkā Vaiṣṇavī, view from N
# 11093                            Gaṇeśa Mandira, Mātṛkā Brahmāṇī, view from N
# 11094                           Gaṇeśa Mandira, Mātṛkā Māheśvarī, view from N
# 11095                           Gaṇeśa Mandira, group of Mātṛkās, view from N
# 11096                              Gaṇeśa Mandira, Mātṛkā Vārāhī, view from N
# 11097                                             Gaṇeśa Mandira, view from W
# 11098                    Gaṇeśa Mandira, statue of standing Śiva, view from W
# 11099                    Gaṇeśa Mandira, statue of standing Śiva, view from E
# 11100  Gaṇeśa Mandira, statue of Umāmaheśvara inside the sanctum, view from W
# 11595                                      Nāya Hiṭī, Gajalakṣmī, view from W
# 11596                                      Nāya Hiṭī, Gajalakṣmī, view from W
# 11597                                      Nāya Hiṭī, Gajalakṣmī, view from W
# 11599                                      Nāya Hiti, Śivaliṅga, view from NW
# 11896                  Kumbheśvara Mandira, Caturmukha Śivaliṅga, view from E
# 13252                                            Dhalāṃkva Hiti, view from NW
# 13256                                   Dhalāṃkva Hiti, close-up view, from S
# 13257                                             Dhalāṃkva Hiti, view from S
# 13258                                            Dhalāṃkva Hiti, view from SW
# 13259                   Dhalāṃkva Hiti, aniconic stone of Gaṇeśa, view from S
# 13261                     Dhalāṃkva Hiti, statue of Umāmaheśvara, view from E
# 13262                                             Dhalāṃkva Hiti, view from E
# 13263                                             Dhalāṃkva Hiti, view from W
# 13594                       Subāhāḥ Hiti Phalcā, Mātṛkā Vaiṣṇavī, view from S
# 19990                                   Misā Hiti, pair of Yakṣa, view from S
# 20125                                 Lāchi Hiti, Yakṣa-Caryatid, view from E
# 21210                                   Suntvāḥ Phalcā (South), location map
# 21211                                     Suntvāḥ Phalcā (South), floor plan
# 21213                                        Suntvāḥ Phalcā (South), section
# 21214                                      Suntvāḥ Phalcā (South), site plan
#
#       date1 date2        date date3                 agent          role  \
# 704                1984-03-17               Jürgen Schick  photographer
# 3014                     2021                     1248182     draftsman
# 3015               2022-02-17                     1173868     draftsman
# 3016               2022-02-17                     1173868     draftsman
# 3017               2022-02-17                     1173868     draftsman
# 6133               2011-08-01                     1595955  photographer
# 6136                                       Lain S Bangdel  photographer
# 8695               2022-02-09                     1173885  photographer
# 8696               2022-02-09                     1173885  photographer
# 8703               2022-02-09                     1173885  photographer
# 8704               2022-02-09                     1173885  photographer
# 9605               2022-02-13                     1173868     draftsman
# 9879               2022-02-17                     1238506     draftsman
# 9880                     2021                     1248182     draftsman
# 9881               2022-02-17                     1238506     draftsman
# 9882               2022-02-17                     1238506     draftsman
# 11091              2010-05-31                     1595955  photographer
# 11092              2010-05-31                     1595955  photographer
# 11093              2010-05-31                     1595955  photographer
# 11094              2010-05-31                     1595955  photographer
# 11095              2010-05-31                     1595955  photographer
# 11096              2010-05-31                     1595955  photographer
# 11097              2010-05-31                     1595956  photographer
# 11098              2014-08-29            Victoria Peralta  photographer
# 11099              2014-08-29            Victoria Peralta  photographer
# 11100              2010-05-31                     1595956  photographer
# 11595                    2011                     1595955  photographer
# 11596                    1976                     1595955  photographer
# 11597                    1996        Sukra Sagar Shrestha  photographer
# 11599                    1976                     1595955  photographer
# 11896              1986-04-15                     1248173  photographer
# 13252              2022-01-16                     1173885  photographer
# 13256              2022-01-16                     1173885  photographer
# 13257              2022-01-16                     1173885  photographer
# 13258              2022-01-16                     1173885  photographer
# 13259              2022-01-16                     1173885  photographer
# 13261              2022-01-16                     1173885  photographer
# 13262              2022-01-16                     1173885  photographer
# 13263              2022-01-16                     1173885  photographer
# 13594              1987-01-30               Jürgen Schick  photographer
# 19990              2012-08-27                     1595955  photographer
# 20125              2014-11-16                     1595956  photographer
# 21210                    2021                     1248182     draftsman
# 21211              2022-02-18                     1173868     draftsman
# 21213              2022-02-18                     1173868     draftsman
# 21214              2022-02-18                     1173868     draftsman
#
#       agent2 role2                                       source notes  \
# 704                 Nepalese Stone Sculptures, 2019, vol I, 168
# 3014
# 3015
# 3016
# 3017
# 6133                Nepalese Stone Sculptures, 2019, vol I, 105
# 6136                 Nepalese Stone Sculptures, 2019, vol I,153
# 8695
# 8696
# 8703
# 8704
# 9605
# 9879
# 9880
# 9881
# 9882
# 11091                Nepalese Stone Sculptures, 2019, vol I, 65
# 11092                Nepalese Stone Sculptures, 2019, vol I, 65
# 11093                Nepalese Stone Sculptures, 2019, vol I, 65
# 11094                Nepalese Stone Sculptures, 2019, vol I, 65
# 11095                Nepalese Stone Sculptures, 2019, vol I, 64
# 11096                Nepalese Stone Sculptures, 2019, vol I, 65
# 11097               Nepalese Stone Sculptures, 2019, vol I, 170
# 11098               Nepalese Stone Sculptures, 2019, vol I, 179
# 11099               Nepalese Stone Sculptures, 2019, vol I, 179
# 11100               Nepalese Stone Sculptures, 2019, vol I, 179
# 11595                Nepalese Stone Sculptures, 2019, vol I, 41
# 11596                Nepalese Stone Sculptures, 2019, vol I, 41
# 11597                Nepalese Stone Sculptures, 2019, vol I, 41
# 11599               Nepalese Stone Sculptures, 2019, vol I, 169
# 11896               Nepalese Stone Sculptures, 2019, vol I, 161
# 13252
# 13256
# 13257
# 13258
# 13259
# 13261
# 13262
# 13263
# 13594                Nepalese Stone Sculptures, 2019, vol I, 54
# 19990               Nepalese Stone Sculptures, 2019, vol I, 105
# 20125                Nepalese Stone Sculptures, 2019, vol I, 96
# 21210
# 21211
# 21213
# 21214
#
#         mon_id class_code         classification   agent3 date_scan
# 704    LAL1860  4002855-0  Architekturfotografie
# 3014   SKH0222  4029783-4                  Karte  1173868
# 3015   SKH0222  4068827-6   Architekturzeichnung
# 3016   SKH0222  4068827-6   Architekturzeichnung
# 3017   SKH0222  4068827-6   Architekturzeichnung
# 6133   LAL1600  4002855-0  Architekturfotografie
# 6136   LAL1600  4002855-0  Architekturfotografie
# 8695   SKH0260  4002855-0  Architekturfotografie
# 8696   SKH0260  4002855-0  Architekturfotografie
# 8703   SKH0260  4002855-0  Architekturfotografie
# 8704   SKH0260  4002855-0  Architekturfotografie
# 9605   SKH0290  4068827-6   Architekturzeichnung
# 9879   SKH0191  4068827-6   Architekturzeichnung
# 9880   SKH0191  4029783-4                  Karte  1238506
# 9881   SKH0191  4068827-6   Architekturzeichnung
# 9882   SKH0191  4068827-6   Architekturzeichnung
# 11091  KIR0055  4002855-0  Architekturfotografie
# 11092  KIR0055  4002855-0  Architekturfotografie
# 11093  KIR0055  4002855-0  Architekturfotografie
# 11094  KIR0055  4002855-0  Architekturfotografie
# 11095  KIR0055  4002855-0  Architekturfotografie
# 11096  KIR0055  4002855-0  Architekturfotografie
# 11097  KIR0055  4002855-0  Architekturfotografie
# 11098  KIR0055  4002855-0  Architekturfotografie
# 11099  KIR0055  4002855-0  Architekturfotografie
# 11100  KIR0055  4002855-0  Architekturfotografie
# 11595  LAL1660  4002855-0  Architekturfotografie
# 11596  LAL1660  4002855-0  Architekturfotografie
# 11597  LAL1660  4002855-0  Architekturfotografie
# 11599  LAL1660  4002855-0  Architekturfotografie
# 11896  LAL1050  4002855-0  Architekturfotografie
# 13252  SKH0156  4002855-0  Architekturfotografie
# 13256  SKH0156  4002855-0  Architekturfotografie
# 13257  SKH0156  4002855-0  Architekturfotografie
# 13258  SKH0156  4002855-0  Architekturfotografie
# 13259  SKH0156  4002855-0  Architekturfotografie
# 13261  SKH0156  4002855-0  Architekturfotografie
# 13262  SKH0156  4002855-0  Architekturfotografie
# 13263  SKH0156  4002855-0  Architekturfotografie
# 13594  LAL4009  4002855-0  Architekturfotografie
# 19990  LAL1051  4002855-0  Architekturfotografie
# 20125  THK0021  4002855-0  Architekturfotografie
# 21210  SKH0224  4029783-4                  Karte  1173868
# 21211  SKH0224  4068827-6   Architekturzeichnung
# 21213  SKH0224  4068827-6   Architekturzeichnung
# 21214  SKH0224  4068827-6   Architekturzeichnung

# %% [markdown]
# ### Checking for caption fixes

# %%
to_fix = list_from_txt("mon\\upload_to_fix.mon")
upload_fix = danam_df.loc[danam_df['mon_id'].isin(to_fix)]
upload_fix = upload_fix.loc[upload_fix['danam_caption'].str.contains("Attribution 40")]

fixes = ["If not otherwise stated, all images and texts in this folder are published under Creative Commons"
, "If not otherwise stated, all images and texts in this monument folder are published under Creative Commons"
, "Attribution 4.0 License \(CC BY-SA 4.0\),"
, "Attribution 40 License \(CC BY-SA 40\),"
, "and the copyright lies with NHDP. All visuals of this monument folder"
," and more are \(or will be\) also stored in heidICON," 
, "and more are also stored in heidICON,"
, "the object and multimedia database of Heidelberg University" 
, "\(Type the ID-number or key words in the first line and click the search field.\)" 
, "\(type the ID-number or key words in the first line and click the search field.\)" 
, "\(type the ID-number or key words in the first line and click the search field\)" 
, "\(type the ID-number or keywords in the first line and click the search field\)." 
, "You will also find the initial report there"
, "The latest report will always be available in DANAM \(this page\)."
, "You will also find the initial report there. The latest report will always be available in DANAM \(this page\)."
, "."
]

for fix in fixes:
    upload_fix['caption'] = upload_fix['caption'].str.replace(fix, '', regex=True, case=False)

upload_fix['caption'] = upload_fix['caption'].str.strip()

# %% [markdown]
# ## Exporting Results to CSV for Weekly Metadata Transfer

# %%
# Writing to CSV 
cols = [
        'filename', 'caption', 'date1', 'date2', 'date', 'date3', 'agent', 'role', 'agent2', 'role2',
        'copyright', 'source', 'empty_column', 'notes', 'mon_id', 'class_code', 'classification', 'agent3', 'date_scan',
        'license', 'url', 'rights_text', 'heidata', 'heidoc'
        ]

all_upload = pd.concat([to_upload, upload_map, upload_historical, to_update])
all_upload.to_csv("csv/image_metadata_.csv", columns=cols, header=True, sep=';', index=False, quotechar = "\"", quoting=csv.QUOTE_ALL)
