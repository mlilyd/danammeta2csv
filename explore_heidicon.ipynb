# %% [markdown]
# # Tests and Ideas
#
# For testing new ideas before it can be integrated with the rest of the workflow

# %%
import pandas as pd
#import scripts.heidICON as heidicon
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# %%
heidicon_df = pd.read_excel("heidicon_export.xlsx")

# %%
# query through metadata table based on mon id
mon_id = 'LAL4138'
##############################
print("Monument ID: {}".format(mon_id))
mon = heidicon_df.loc[(heidicon_df['obj_systematik']==mon_id) | (heidicon_df['obj_systematik']==mon_id.upper())]
print("Number of images in DANAM: {}".format(mon.shape[0]))
##############################
# Out:
# Monument ID: LAL4138
# Number of images in DANAM: 17

# %%
mon
# Out:
#     _system_object_id     _id  _version        _last_modified  \
# 45            1170030  568371         9  2020-12-19T13:50:38Z
# 46            1170031  568372        11  2021-05-18T10:10:45Z
# 47            1170032  568373        10  2021-05-18T10:10:45Z
# 48            1170033  568374        11  2020-12-11T06:01:41Z
# 49            1170034  568375         9  2020-12-19T13:50:38Z
# 50            1170035  568376         9  2020-12-19T13:50:38Z
# 51            1170036  568377         9  2020-12-19T13:50:38Z
# 52            1170037  568378        12  2021-05-18T10:12:55Z
# 53            1170038  568379        10  2021-02-15T15:15:31Z
# 54            1170039  568380        10  2021-02-15T15:15:31Z
# 55            1170040  568381         9  2020-12-19T13:50:38Z
# 56            1170041  568382        10  2021-05-18T10:10:45Z
# 57            1170042  568383        10  2021-05-18T10:10:45Z
# 58            1170043  568384        10  2021-05-18T10:10:45Z
# ...
